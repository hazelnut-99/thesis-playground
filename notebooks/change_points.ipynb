# %%
from ocpdet import EWMA
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2025-05-19 14:08:52.484026: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-19 14:08:52.491957: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-19 14:08:52.519061: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747678132.565566 1600126 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747678132.579518 1600126 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747678132.614222 1600126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747678132.614261 1600126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747678132.614266 1600126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747678132.614270 1600126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-19 14:08:52.624839: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
np.random.seed(42)

data = np.concatenate([
    np.random.normal(loc=0., scale=1., size=(100,)),
    np.random.normal(loc=3., scale=1., size=(100,)),
    np.random.normal(loc=1., scale=1., size=(100,)),
])

plt.figure(figsize=(10, 3))
plt.scatter(range(0, len(data)), data, c="b", s=20)
plt.plot(range(0, len(data)), data, c="b")
plt.xlabel("Time")
plt.ylabel("Observations")
plt.axvline(100, min(data), max(data), color="r", linestyle="--")
plt.axvline(200, min(data), max(data), color="r", linestyle="--")
plt.show()

# %%
model = EWMA(r=0.15, L=2.4, burnin=50, mu=0., sigma=1.)

# %%
model.process(data)

# %%
model.changepoints
# Out:
# [102, 204]
